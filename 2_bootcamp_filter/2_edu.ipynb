# %%
import pandas as pd
import re
import numpy as np
fileOut = "2_educ_boots.xlsx"

# %%
df = pd.read_csv("DF_BOOTCAMPS_2591.csv")

# %%
#CONSERVAR A TODOS AQUELLOS QUE NO TENGAN MISSING VALUES EN EDUCATION Y CERTIFICATION. 

dfe = df[df["education"].notna()] #DATAFRAME DE EDUCATION
dfe = dfe.reset_index(drop = True) #REINICIAR INDICE

dfc = df[df["certifications"].notna()] #DATAFRAME DE CERTIFICACIÓN

# %%
dfe.columns
# Out:
# Index(['id', 'scraping_services_id', 'linkedin_id', 'linkedin_profile_url',
#        'last_name', 'first_name', 'v_extension', 'location', 'job_title',
#        'company', 'job_history', 'snapshots', 'skills', 'education', 'about',
#        'updated', 'middle_name', 'num_connections', 'interests', 'volunteered',
#        'certifications', 'languages', 'recommendations', 'publications',
#        'patents', 'industry', 'titles', 'company_name_complete',
#        'job_title_complete'],
#       dtype='object')

# %%
dfe.shape
# Out:
# (2566, 29)

# %%
# REGEX DE BOOTCAMPS
boots =['4[ -]?geeks',
 'ac.mica',
 'ada.?itw',
 'bedu[ -]?tech', 
 'bogot.[ -]?dev| bogot.[ -]?bootcamp',
 'bootcamp[ -]?institute',
 'coderise|coderise.?international',
 'desaf.o[ -]?latam',
 'dev ?f\.',
 'dev f\\.'
 'digital[ -]?house',
 'generation[ -]?m.xico',
 'hack.?academy',
 'hola.?code',
 'holberton.?school',
 'icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding',
 'ijalti', 
 'iron.?hack',
 'j.venes[ -]?a[ -]?programar',
 'keep.?coding',
 'kod[ -]?1[ -]?go',
 'laborat.ria ', 
 'le.?wagon', 
 'make[ -]?it[ -]?real[ -]?camp| make[ -]?it[ -]?real',
 'mind.?hub',
 'muktek|muk.?tek', 
 'nivel[ -]?pro ', 
 'noukod|noukood|noukd', 
 'plataforma[ -]?5',
 'programa[ -]?valentina',
 'reprograma',
 'worldtech', 
 'bictia|bi.?tia', 
 'talento[ -]?digital']

# %% [markdown]
# # EXTRAER FORMACIÓN DESDE EL DATASET DE LOS NO-MISSING VALUES DE EDUCACIÓN

# %%
#CONVERTIR EN STRING
dfe["education"] =  dfe["education"].str.lower()

# %%
#CONVERTIR EN DICCIONARIOS LA EDUCACIÓN
L = []

for i in dfe["education"]:
    l = str(i).split("},") #convertir en string la formación del individuo y crear lista para separar cada formación
    k = [] #Lista donde se almacenara cada formación x del individuo i
    for formacion in l: #para cada formación
        formacion = formacion.replace("[", "").replace("]", "") + "}" #separelas y conviertalas en diccionarios
        k.append(formacion) #añadalas a la lista de formación
    L.append(k) #añada la lista de formación para individuo

#VER UN EJEMPLO: Esta es la última formación del primer individuo desordenada en diccionario pero como un string   
L[0][0]
# Out:
# "{'education_org': 'university of oxford', 'degrees': 'university of oxford – oxford royale academy, english and culture, common european framework of reference: profiecient user', 'end': '2013', 'start': '2013'}"

# %%
K = [] #LISTA D ELISTAS EN DONDE SE ALMACENARAN LAS FORMACIONES A MANERA DE DICCIONARIO PARA CADA INDIVIDUO

for individuo in L: #para cada individuo

    educacion_ind = [] #creo una lista de sus educaciones

    for ins in individuo: # para cada cada formación dentro de las formaciones de cada individuos
        ins = ins.replace('"', "'")

        c = {}

        #CADA CAMPO SE EXTRAE POR MEDIO DE RegEx, COMUNES A TODOS LAS FORMACIONES STR DE LOS INDIVIDUOS EN EL DATASET
        #CADA CAMPO SE EXTRAE EN CASO DE QUE EXISTA DE LO CONTRARIO NO

        #EXTRAER EDUCACIÓN
        if ( len(re.findall("'education_org': '.*?'", ins)) ) > 0:
            c["education"] =  re.findall("'education_org': '.*?'", ins)[0].replace("'education_org': ", "").replace("'", "")

        #EXTRAER DEGREE
        if ( len(re.findall("'degrees': '.*?'", ins)) ) > 0:
            c["degrees"] =  re.findall("'degrees': '.*?'", ins)[0].replace("'degrees': ", "").replace("'", "")

        #EXTRAER SUMMARY
        if ( len(re.findall("'summary': '.*?'", ins)) ) > 0:
            c["summary"] =  re.findall("'summary': '.*?'", ins)[0].replace("'summary': ", "").replace("'", "")


        #EXTRAER INICIO
        if ( len(re.findall("'start': '.*?'", ins)) ) > 0:
            c["start"] = re.findall("'start': '.*?'", ins)[0].replace("'start': ", "").replace("'", "")

        #EXTRAER FINALIZACIÓN
        if ( len(re.findall("'end': '.*?'", ins)) ) > 0:
            c["end"] = re.findall("'end': '.*?'", ins)[0].replace("'end': ", "").replace("'", "")

        educacion_ind.append(c) #añado cada formación a la lista de sus educaciones
    
    K.append(educacion_ind) #añado la educación de cada individuo a una lista general

#VER UN EJEMPLO: Esta es la última formación del primer individuo ordenada en un diccionario
K[0][0]
# Out:
# {'education': 'university of oxford',
#  'degrees': 'university of oxford – oxford royale academy, english and culture, common european framework of reference: profiecient user',
#  'start': '2013',
#  'end': '2013'}

# %%
#CREAR COLUMNA LIMPIA DE EDUCACIÓN
dfe["educacion"] = K

# %%
#VER UN EJEMPLO: Esta es la última formación del primer individuo ordenada en un diccionario
dfe.educacion[0][2]
# Out:
# {'education': 'vrije universiteit amsterdam',
#  'degrees': '(pre)-master, organization science',
#  'summary': '(schakeljaar tussen hbo-opleiding en masterstudie)\\n afstudeeronderzoek bij het ministerie van sociale zaken en werkgelegenheid(szw)\\n onderzoek op welke manier(en) de invoering van ‘het nieuwe werken’ bij het ministerie van szw, invloed heeft (gehad) op de betrokkenheid van de werknemers bij het uitvoeren hun werkzaamheden.\\n activities and societies: lid van faculteitsvereniging eos',
#  'start': '2011',
#  'end': '2012'}

# %%
lista_boots = ['4Geeks',
 'Acámica',
 'Ada ITW',
 'Bedu Tech',
 'Bogotá Dev',
 'Bootcamp Institute',
 'Coderise International',
 'Desafío Latam',
 'Dev F.',
 'Digital House',
 'Generation Mexico',
 'Hack Academy',
 'HolaCode',
 'Holberton School',
 'iCreate Coding Academy',
 'IJALTI',
 'Iron Hack',
 'Jóvenes a Programar',
 'Keep Coding',
 'Kod1go',
 'Laboratoria',
 'Le Wagon',
 'Make it Real Camp',
 'MindHub ',
 'Muktek Academy',
 'Nivel Pro',
 'Noukod',
 'Plataforma 5',
 'Programa Valentina',
 'Pygmalion',
 'Reprograma',
 'World Tech Inc (a.k.a. World Tech Makers –WTM–)',
 'BICTIA',
 'Talento Digital']

# %%
# REGEX DE BOOTCAMPS
boots =['4[ -]?geeks',
 'ac.mica',
 'ada.?itw',
 'bedu[ -]?tech', 
 'bogot.[ -]?dev| bogot.[ -]?bootcamp',
 'bootcamp[ -]?institute',
 'coderise|coderise.?international',
 'desaf.o[ -]?latam',
 'dev ?f\.',
 'digital[ -]?house',
 'generation[ -]?m.xico',
 'hack.?academy',
 'hola.?code',
 'holberton.?school',
 'icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding',
 'ijalti', 
 'iron.?hack',
 'j.venes[ -]?a[ -]?programar',
 'keep.?coding|keep.?coding.io',
 'kod[ -]?1[ -]?go',
 'laborat.ria ', 
 'le.?wagon', 
 'make[ -]?it[ -]?real[ -]?camp| make[ -]?it[ -]?real',
 'mind.?hub',
 'muktek|muk.?tek', 
 'nivel[ -]?pro ', 
 'noukod|noukood|noukd', 
 'plataforma[ -]?5',
 'programa[ -]?valentina',
 'pygmalion'
 'reprograma',
 'worldtech$',  #se cambió  para que solo termine con $
 'bictia|bi.?tia', 
 'talento[ -]?digital$'] #

 #VERDE: MÁS GRANDES DE LA, #AMARILLOS: MEDIANOS
 #EN PRINCIPIOS LOS VERDES SON LOS QUE DEBERIAN APARECER MÁS EN LOS PERFILES, EN PRINCIPIO.


 #BASE: LINKED-IN: + DIFICIL PARA HACER SCRAPING. EMPRESAS VENDEN DATOS (OBTUVIERON HACIENDO SCRAPING), PERFILES EGRESADOS DE BOOTCAMPS DE LISTA DE BOOTCAMPS EN LA. 3 RONDAS DE INTENTOS Y MANDAN MUESTRA PEQUEÑA. SUGIEREN MUCHOS DE LOS CAMBIOS.abs

 #NEGOCIACIÓN, PERFILES Y CUÁNTO CUESTA. MAX 8MIL. CADA FALSO POSITIVO ES UN PROBLEMA. 
 # LLEGABAN A MIL, PARECIA QUE FP NO ERAN PROBLEMA: MEJOR ESTRATEGIA PALABRAS GENERALES Y TRAEMOS 5MIL PERFILES Y DENTRO DE ESA DEBEN DE ESTAR TODOS ESTUDIANTES DE PERFILES PROFESIONALES DE BOOTCAMPS.
 # EGRESADOS EN LATIRNOAMERICA DEBERÍAN SER MUCHO MÁS DE 8MIL, EJ: DIGITAL HOUSE HABLAN DE 100MIL EGRESADOS

 #NO REPRESENTATIVIDAD: MUCHOS EGRESADOS POCA MUESTRA, NO TODOS TIENEN PERFIL DE LINKED-IN

 #PRIORIDAD

# %%
#LOOP PARA BUSCAR SI EL INDIVIDUO TIENE FORMACIÓN EN ALGÚN BOOTCAMP
c = []
for boot in range(len(boots)): #PARA CADA BOOTCAMP
    for i in range(len(dfe.educacion)): #PARA CADA INDIVIDUO
        for h in range(len(dfe.educacion[i])): #DENTRO LA EDUCACIÓN DE CADA INDIVIDUO
            if "education" in dfe.educacion[i][h]: #SI TIENE EL CAMPO EDUCACIÓN
                A = re.findall(boots[boot], dfe.educacion[i][h]["education"]) #REVISA SI ESTÁ EN UN BOOTCAMP
                if len(A) > 0 : #SI ESA REVISIÓN ES NO VACÍA
                    c.append((dfe.id[i], boots[boot], lista_boots[boot], dfe.educacion[i][h]['education']))
                    # c.append((dfe.id[i], h)) #AÑADE EL ID DE ESE INDIVIDUO Y EL LUGAR DONDE ESTÁ ESA EDUCACIÓN
                    print(f"{dfe['job_title'][i]}---{A}---{boots[boot]}--{dfe.educacion[i][h]['education']} \n \n")


            #LOOP SIN INDICE
            # for edu in dfe.educacion[i]:
            # if "education" in edu:
            #     # print(boot, edu["education"])
            #     A = re.findall(boot, edu["education"])
            #     if len(A) > 0:
            #         c.append(A)
            #         m.append(boot)
            #         print(f" {dfe['job_title'][i]} -- {A} -- {boot} -- {edu['education']} \n \n")
            #         # print(f"{A} -- {boot} -- {edu['education']}")
# Out:
# CEO---['acamica']---ac.mica--acamica
#
#
# Co-founder & CEO---['acamica']---ac.mica--acamica
#
#
# Web Full Stack Developer---['acamica']---ac.mica--acamica
#
#
# Ingeniero---['acamica']---ac.mica--acamica
#
#
# Senior Javascript Developer---['acamica']---ac.mica--codecademy/acamica
#
#
# Technical Support Engineer---['acamica']---ac.mica--acamica
#
#
# Lider de Ecommerce---['acamica']---ac.mica--acamica
#
#
# API - UI Automation---['acamica']---ac.mica--globant & acamica
#
#
# Coordinadora de Marketing Digital---['acamica']---ac.mica--acamica.com
#
#
# Student---['acamica']---ac.mica--acamica
#
#
# Student---['acamica']---ac.mica--acamica
#
#
# Solution Developer. Frontend Developer (Angular)---['acamica']---ac.mica--acamica
#
#
# Solution Developer. Frontend Developer (Angular)---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# Sr UI/UX Designer---['acamica']---ac.mica--acamica
#
#
# Analista Senior del Banco Central de---['acamica']---ac.mica--acamica
#
#
# Analista Senior del Banco Central de---['acamica']---ac.mica--acamica
#
#
# estudiante Coderise---['coderise']---coderise|coderise.?international--coderise
#
#
# Líder de Experiencia Usuario (UX) ----['desafio latam']---desaf.o[ -]?latam--academia desafio latam
#
#
# nan---['desafio latam']---desaf.o[ -]?latam--desafio latam
#
#
# Product Manager---['digital house']---digital[ -]?house--digital house
#
#
# Ejecutivo de cuentas---['digital house']---digital[ -]?house--digital house
#
#
# Social Media Intelligence & Marketing Research---['digital house']---digital[ -]?house--digital house
#
#
# Administración---['digital house']---digital[ -]?house--digital house
#
#
# English > Spanish Subtitler---['digital house']---digital[ -]?house--digital house
#
#
# Agile Coach---['digital house']---digital[ -]?house--digital house
#
#
# nan---['digital house']---digital[ -]?house--digital house
#
#
# Digital Acquisition---['digital house']---digital[ -]?house--digital house
#
#
# Ejecutivo de Ventas---['digital house']---digital[ -]?house--digital house
#
#
# Sales Team Lead, EU Marketplace Expansion---['digital house']---digital[ -]?house--digital house
#
#
# International Consultant---['digital house']---digital[ -]?house--digital house
#
#
# District Manager---['digital house']---digital[ -]?house--digital house
#
#
# Responsable de caja---['digital house']---digital[ -]?house--digital house
#
#
# Customer Success Manager---['digital house']---digital[ -]?house--digital house
#
#
# Customer Success Manager---['digital house']---digital[ -]?house--digital house
#
#
# Gerente de Calidad---['digital house']---digital[ -]?house--digital house
#
#
# Front End Lead Developer---['digital house']---digital[ -]?house--digital house
#
#
# Product enthusiast---['digital house']---digital[ -]?house--digital house coding school
#
#
# Recursos Humanos---['digital house']---digital[ -]?house--digital house
#
#
# Marketing Specialist---['hack academy']---hack.?academy--biohack academy
#
#
# Open Source Low-Cost Prototypes Developer---['hack academy']---hack.?academy--biohack academy i + 8-week extension at waag society, amsterdam nl
#
#
# principal---['hack academy']---hack.?academy--hack academy
#
#
# Making Technology flexible for Business use---['icreate']---icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding--icreate
#
#
# Marketing Director---['ironhack']---iron.?hack--ironhack
#
#
# Consultant---['ironhack']---iron.?hack--ironhack
#
#
# Head of Strategy---['ironhack']---iron.?hack--ironhack
#
#
# Frontend Developer---['ironhack']---iron.?hack--ironhack
#
#
# Chief Technology Officer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding.es
#
#
# Big Data Product Owner---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Mobile Software developer---['keepcoding']---keep.?coding|keep.?coding.io--startup engineering master bootcamp by keepcoding
#
#
# iOS & Android Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Fullstack developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Programmer analyst In Indizen---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Senior iOS developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Mobile Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding.io
#
#
# Computer Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Ingeniero I+D+i---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Backend developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding.io
#
#
# nan---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Full Stack JavaScript Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Full Stack Developer---['keep coding']---keep.?coding|keep.?coding.io--keep coding
#
#
# Full Stack Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Backend Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# IOS Developer---['keep coding']---keep.?coding|keep.?coding.io--keep coding (agbo training)
#
#
# Desarrollo de apps móviles y Comunicación---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Senior Software Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding startup engineering master bootcamp
#
#
# CTO---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Fullstack Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding®
#
#
# Senior Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Functional Analyst---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding startup engineering master bootcamp
#
#
# Senior IOS Developer---['keepcoding']---keep.?coding|keep.?coding.io--agbo - keepcoding master bootcamp
#
#
# Senior iOS Developer---['keep coding']---keep.?coding|keep.?coding.io--keep coding (agbo training)
#
#
# Mobile Development Engineer---['keepcoding']---keep.?coding|keep.?coding.io--master keepcoding.io
#
#
# Senior iOS Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Computer Science Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Senior Devops Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Senior Software Engineer - Mobile---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# IT Project Manager---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Team Lead---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Front-End Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# ecmo specialist---['laboratoria ']---laborat.ria --laboratoria spolocnosti medtronic, kerkrade
#
#
# Founder Barrio Fluido---['laboratoria ']---laborat.ria --laboratoria perú
#
#
# Web Designer---['laboratoria ']---laborat.ria --laboratoria méxico
#
#
# Web Designer---['laboratoria ']---laborat.ria --laboratoria méxico
#
#
# Consultor Externo---['laboratoria ']---laborat.ria --laboratoria de idiomas uba
#
#
# IT Business Analyst---['laboratoria ']---laborat.ria --laboratoria mexico
#
#
# owner---['laboratoria ']---laborat.ria --laboratoria di affresco di elena e leonetto tintori
#
#
# Empresa dedicada a---['laboratoria ']---laborat.ria --laboratoria a.s.
#
#
# Maquillador---['laboratoria ']---laborat.ria --laca laboratoria de cosmetica avanzada
#
#
# Desarrolladora Front-end---['laboratoria ']---laborat.ria --laboratoria - perú
#
#
# Comunicadora & WebDeveloper---['laboratoria ']---laborat.ria --laboratoria code school
#
#
# Lead---['le wagon']---le.?wagon--le wagon coding bootcamp
#
#
# VP Latam---['le wagon']---le.?wagon--le wagon
#
#
# COO---['le wagon']---le.?wagon--le wagon
#
#
# Cofounder Le Wagon LATAM---['le wagon']---le.?wagon--le wagon
#
#
# Airbnb---['plataforma 5']---plataforma[ -]?5--plataforma 5
#
#
# Business Data Science Consultant---['plataforma 5']---plataforma[ -]?5--plataforma 5 - coding school
#
#
# Directora---['plataforma 5']---plataforma[ -]?5--plataforma 5
#
#
# Directora---['plataforma 5']---plataforma[ -]?5--plataforma 5
#
#
# Founder---['plataforma 5']---plataforma[ -]?5--plataforma 5
#
#
# IT Operation Analyst---['worldtech']---worldtech$--worldtech
#
#
# Freelance Developer---['worldtech']---worldtech$--worldtech
#
#
# Freelance Developer---['worldtech']---worldtech$--worldtech
#
#
# Startup Ecosystem Builder---['talento digital']---talento[ -]?digital$--nomadia.es escuela de talento digital
#
#
# Ideation Lead (UNIR_Gen)---['talento digital']---talento[ -]?digital$--nomadia, escuela de talento digital

# %%
#CREAR DATAFRAME

c = list(set(c))
educ_boots = pd.DataFrame.from_records(c, columns=['id', 'regex_bootcamp', 'bootcamp', "educ_title"])

# %%
#HACER MERGE CON EL RESTO DE COLUMNAS
educ_boots = pd.merge(educ_boots, dfe, "left", "id")
educ_boots.to_excel(fileOut, index = False)

# %%
print(educ_boots)
# Out:
#           id                regex_bootcamp       bootcamp  \
# 0   34372997                 hack.?academy   Hack Academy
# 1   47714089                       ac.mica        Acámica
# 2   31363775             digital[ -]?house  Digital House
# 3   66954076          talento[ -]?digital$         BICTIA
# 4   77852405                       ac.mica        Acámica
# ..       ...                           ...            ...
# 95  51538550  keep.?coding|keep.?coding.io    Keep Coding
# 96  53846115  keep.?coding|keep.?coding.io    Keep Coding
# 97  53846062  keep.?coding|keep.?coding.io    Keep Coding
# 98  21267548                  laborat.ria     Laboratoria
# 99  67824354  keep.?coding|keep.?coding.io    Keep Coding
#
#                                         educ_title  scraping_services_id  \
# 0                                     hack academy              34372997
# 1                                          acamica              47714089
# 2                                    digital house              31363775
# 3              nomadia, escuela de talento digital              66954076
# 4                                          acamica              77852405
# ..                                             ...                   ...
# 95                                      keepcoding              51538550
# 96               agbo - keepcoding master bootcamp              53846115
# 97  keepcoding startup engineering master bootcamp              53846062
# 98                                laboratoria perú              21267548
# 99                                      keepcoding              67824354
#
#                                  linkedin_id  \
# 0                     david-barrett-60a770a1
# 1   rodolfo-alexander-silva-pantoja-b1573934
# 2                              hernanparedes
# 3                           begonaantonplaza
# 4                  gustavodanielromerosantos
# ..                                       ...
# 95                                jlgarciaap
# 96              carmeloruymanquintanasantana
# 97                                  fjaranda
# 98        jesenia-rodríguez-paredes-3077abba
# 99              ramón-albertí-danés-22837140
#
#                                  linkedin_profile_url last_name first_name  \
# 0   https://www.linkedin.com/in/david-barrett-60a7...   Barrett      David
# 1   https://www.linkedin.com/in/rodolfo-alexander-...   Pantoja    Rodolfo
# 2           https://www.linkedin.com/in/hernanparedes   Paredes     Hernan
# 3        https://www.linkedin.com/in/begonaantonplaza     Plaza     Begoña
# 4   https://www.linkedin.com/in/gustavodanielromer...    Santos    Gustavo
# ..                                                ...       ...        ...
# 95             https://www.linkedin.com/in/jlgarciaap  Aparicio       Juan
# 96  https://www.linkedin.com/in/carmeloruymanquint...   Santana    Carmelo
# 97               https://www.linkedin.com/in/fjaranda    García  Francisco
# 98  https://www.linkedin.com/in/jesenia-rodríguez-...   Paredes    Jesenia
# 99  https://www.linkedin.com/in/ramón-albertí-dané...     Danés      Ramón
#
#                                           v_extension  ...  \
# 0   {'gender': 'male', 'industry_from_job': False,...  ...
# 1   {'gender': 'male', 'industry_from_job': False,...  ...
# 2   {'gender': 'male', 'industry_from_job': 'Infor...  ...
# 3   {'gender': False, 'industry_from_job': None, '...  ...
# 4   {'gender': 'male', 'industry_from_job': 'Manag...  ...
# ..                                                ...  ...
# 95  {'gender': 'male', 'industry_from_job': 'Compu...  ...
# 96  {'gender': 'male', 'industry_from_job': 'Compu...  ...
# 97  {'gender': 'male', 'industry_from_job': 'Manag...  ...
# 98  {'gender': False, 'industry_from_job': False, ...  ...
# 99  {'gender': False, 'industry_from_job': 'Comput...  ...
#
#                                        certifications  \
# 0                                                 NaN
# 1   [{'certificate_authority': 'Oracle', 'end': 'P...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  [{'certificate_authority': 'PECB', 'end': 'Mar...
# 96                                                NaN
# 97  [{'certificate_authority': 'The George Washing...
# 98                                                NaN
# 99  [{'certificate_authority': 'Mejorando.la INC',...
#
#                              languages  \
# 0                                  NaN
# 1                           ['Inglés']
# 2              ['Portugues', 'Inglés']
# 3                           ['Inglés']
# 4   ['Inglés', 'Portugués', 'Spanish']
# ..                                 ...
# 95                         ['English']
# 96                                 NaN
# 97    ['Español', 'Inglés', 'Francés']
# 98               ['Español', 'Inglés']
# 99               ['Inglés', 'Catalán']
#
#                                       recommendations  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ['Hernan foi capaz de mudar profundamente a fo...
# 3   ['Lo que más destacaría de Begoña es que una p...
# 4   ['He conocido a Gustavo fuera del ambiente lab...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  ['Francisco Javier ha sido compañero durante v...
# 98                                                NaN
# 99  ['Ramón has an aptitude for logics and underst...
#
#                                          publications patents  \
# 0                                                 NaN     NaN
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4   [{'authors': [{'full_name': 'Gustavo Daniel Ro...     NaN
# ..                                                ...     ...
# 95                                                NaN     NaN
# 96                                                NaN     NaN
# 97                                                NaN     NaN
# 98                                                NaN     NaN
# 99                                                NaN     NaN
#
#                              industry titles company_name_complete  \
# 0                                 NaN    NaN                   NaN
# 1   Information Technology & Services    NaN                   NaN
# 2                                 NaN    NaN                   NaN
# 3                                 NaN    NaN                   NaN
# 4                                 NaN    NaN                   NaN
# ..                                ...    ...                   ...
# 95                                NaN    NaN                   NaN
# 96                                NaN    NaN                   NaN
# 97                                NaN    NaN                   NaN
# 98                                NaN    NaN                   NaN
# 99                                NaN    NaN                   NaN
#
#    job_title_complete                                          educacion
# 0                 NaN                    [{'education': 'hack academy'}]
# 1                 NaN  [{'education': 'universidad distrital francisc...
# 2                 NaN  [{'education': 'universidad de buenos aires', ...
# 3                 NaN  [{'education': 'nomadia, escuela de talento di...
# 4                 NaN  [{'education': 'apep asociación civil programa...
# ..                ...                                                ...
# 95                NaN  [{'education': 'keepcoding', 'degrees': 'keepc...
# 96                NaN  [{'education': 'agbo - keepcoding master bootc...
# 97                NaN  [{'education': 'keepcoding startup engineering...
# 98                NaN  [{'education': 'area 51 training center', 'deg...
# 99                NaN  [{'education': 'keepcoding', 'degrees': 'keepc...
#
# [100 rows x 33 columns]
