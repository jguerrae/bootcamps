# %%
import pandas as pd
import re
import numpy as np
## to not overwrite other files
fileOut = "2_cert_aut_boots.xlsx"

# %%
df = pd.read_csv("DF_BOOTCAMPS_2591.csv")

# %%
#CONSERVAR A TODOS AQUELLOS QUE NO TENGAN MISSING VALUES EN EDUCATION Y CERTIFICATION. 



dfc = df[df["certifications"].notna()] #DATAFRAME DE CERTIFICACIÓN
dfc = dfc.reset_index(drop = True) #REINICIAR INDICE

# %%
dfc.columns
# Out:
# Index(['id', 'scraping_services_id', 'linkedin_id', 'linkedin_profile_url',
#        'last_name', 'first_name', 'v_extension', 'location', 'job_title',
#        'company', 'job_history', 'snapshots', 'skills', 'education', 'about',
#        'updated', 'middle_name', 'num_connections', 'interests', 'volunteered',
#        'certifications', 'languages', 'recommendations', 'publications',
#        'patents', 'industry', 'titles', 'company_name_complete',
#        'job_title_complete'],
#       dtype='object')

# %%
dfc.shape
# Out:
# (888, 29)

# %%
# REGEX DE BOOTCAMPS
boots =['4[ -]?geeks',
 'ac.mica',
 'ada.?itw',
 'bedu[ -]?tech', 
 'bogot.[ -]?dev| bogot.[ -]?bootcamp',
 'bootcamp[ -]?institute',
 'coderise|coderise.?international',
 'desaf.o[ -]?latam',
 'dev ?f\.',
 'dev f\\.'
 'digital[ -]?house',
 'generation[ -]?m.xico',
 'hack.?academy',
 'hola.?code',
 'holberton.?school',
 'icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding',
 'ijalti', 
 'iron.?hack',
 'j.venes[ -]?a[ -]?programar',
 'keep.?coding',
 'kod[ -]?1[ -]?go',
 'laborat.ria ', 
 'le.?wagon', 
 'make[ -]?it[ -]?real[ -]?camp| make[ -]?it[ -]?real',
 'mind.?hub',
 'muktek|muk.?tek', 
 'nivel[ -]?pro ', 
 'noukod|noukood|noukd', 
 'plataforma[ -]?5',
 'programa[ -]?valentina',
 'reprograma',
 'worldtech', 
 'bictia|bi.?tia', 
 'talento[ -]?digital']

# %% [markdown]
# # EXTRAER FORMACIÓN DESDE EL DATASET DE LOS NO-MISSING VALUES DE EDUCACIÓN

# %%
#CONVERTIR EN STRING
dfc["certifications"] =  dfc["certifications"].str.lower()

# %%
#CONVERTIR EN DICCIONARIOS LA EDUCACIÓN
L = []

for i in dfc["certifications"]:    
    l = str(i).split("},") #convertir en string la formación del individuo y crear lista para separar cada formación
    k = [] #Lista donde se almacenara cada formación x del individuo i
    for formacion in l: #para cada formación
        #print("ln", formacion)
        formacion = formacion.replace("[", "").replace("]", "") + "}" #separelas y conviertalas en diccionarios
        k.append(formacion) #añadalas a la lista de formación
    L.append(k) #añada la lista de formación para individuo

#VER UN EJEMPLO: Esta es la última formación del primer individuo desordenada en diccionario pero como un string   
L[0][0]
# Out:
# "{'certificate_authority': 'nepal engineering council', 'end': 'present', 'start': 'august 2014', 'title': 'certificate for the registered engineer'}"

# %%
K = [] #LISTA D ELISTAS EN DONDE SE ALMACENARAN LAS FORMACIONES A MANERA DE DICCIONARIO PARA CADA INDIVIDUO
regxCerAuth = "'certificate_authority': '.*?'"
regexTitle = "'title': '.*?'"

for individuo in L: #para cada individuo

    educacion_ind = [] #creo una lista de sus educaciones

    for ins in individuo: # para cada cada formación dentro de las formaciones de cada individuos
        ins = ins.replace('"', "'")

        c = {}

        #CADA CAMPO SE EXTRAE POR MEDIO DE RegEx, COMUNES A TODOS LAS FORMACIONES STR DE LOS INDIVIDUOS EN EL DATASET
        #CADA CAMPO SE EXTRAE EN CASO DE QUE EXISTA DE LO CONTRARIO NO

        #EXTRAER EDUCACIÓN
        if ( len(re.findall("'certificate_authority': '.*?'", ins)) ) > 0:
            c["certificate_authority"] =  re.findall("'certificate_authority': '.*?'", ins)[0].replace("'certificate_authority': ", "").replace("'", "")

        #EXTRAER DEGREE
        if ( len(re.findall(regexTitle, ins)) ) > 0:
            c["title"] =  re.findall("'title': '.*?'", ins)[0].replace("'title': ", "").replace("'", "")

        


        #EXTRAER INICIO
        if ( len(re.findall("'start': '.*?'", ins)) ) > 0:
            c["start"] = re.findall("'start': '.*?'", ins)[0].replace("'start': ", "").replace("'", "")

        #EXTRAER FINALIZACIÓN
        if ( len(re.findall("'end': '.*?'", ins)) ) > 0:
            c["end"] = re.findall("'end': '.*?'", ins)[0].replace("'end': ", "").replace("'", "")

        educacion_ind.append(c) #añado cada formación a la lista de sus educaciones
    
    K.append(educacion_ind) #añado la educación de cada individuo a una lista general

#VER UN EJEMPLO: Esta es la última formación del primer individuo ordenada en un diccionario
K[0][0]
# Out:
# {'certificate_authority': 'nepal engineering council',
#  'title': 'certificate for the registered engineer',
#  'start': 'august 2014',
#  'end': 'present'}

# %%
#CREAR COLUMNA LIMPIA DE EDUCACIÓN
dfc["certifications"] = K

# %%
#VER UN EJEMPLO: Esta es la última formación del primer individuo ordenada en un diccionario
dfc.certifications[0][0]
# Out:
# {'certificate_authority': 'nepal engineering council',
#  'title': 'certificate for the registered engineer',
#  'start': 'august 2014',
#  'end': 'present'}

# %%
lista_boots = ['4Geeks',
 'Acámica',
 'Ada ITW',
 'Bedu Tech',
 'Bogotá Dev',
 'Bootcamp Institute',
 'Coderise International',
 'Desafío Latam',
 'Dev F.',
 'Digital House',
 'Generation Mexico',
 'Hack Academy',
 'HolaCode',
 'Holberton School',
 'iCreate Coding Academy',
 'IJALTI',
 'Iron Hack',
 'Jóvenes a Programar',
 'Keep Coding',
 'Kod1go',
 'Laboratoria',
 'Le Wagon',
 'Make it Real Camp',
 'MindHub ',
 'Muktek Academy',
 'Nivel Pro',
 'Noukod',
 'Plataforma 5',
 'Programa Valentina',
 'Pygmalion',
 'Reprograma',
 'World Tech Inc (a.k.a. World Tech Makers –WTM–)',
 'BICTIA',
 'Talento Digital']

# %%
# REGEX DE BOOTCAMPS
boots =['4[ -]?geeks',
 'ac.mica',
 'ada.?itw',
 'bedu[ -]?tech', 
 'bogot.[ -]?dev| bogot.[ -]?bootcamp',
 'bootcamp[ -]?institute',
 'coderise|coderise.?international',
 'desaf.o[ -]?latam',
 'dev ?f\.',
 'digital[ -]?house',
 'generation[ -]?m.xico',
 'hack.?academy',
 'hola.?code',
 'holberton.?school',
 'icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding',
 'ijalti', 
 'iron.?hack',
 'j.venes[ -]?a[ -]?programar',
 'keep.?coding|keep.?coding.io',
 'kod[ -]?1[ -]?go',
 'laborat.ria ', 
 'le.?wagon', 
 'make[ -]?it[ -]?real[ -]?camp| make[ -]?it[ -]?real',
 'mind.?hub',
 'muktek|muk.?tek', 
 'nivel[ -]?pro ', 
 'noukod|noukood|noukd', 
 'plataforma[ -]?5',
 'programa[ -]?valentina',
 'pygmalion'
 'reprograma',
 'worldtech$',  #se cambió  para que solo termine con $
 'bictia|bi.?tia', 
 'talento[ -]?digital$'] #

 #VERDE: MÁS GRANDES DE LA, #AMARILLOS: MEDIANOS
 #EN PRINCIPIOS LOS VERDES SON LOS QUE DEBERIAN APARECER MÁS EN LOS PERFILES, EN PRINCIPIO.


 #BASE: LINKED-IN: + DIFICIL PARA HACER SCRAPING. EMPRESAS VENDEN DATOS (OBTUVIERON HACIENDO SCRAPING), PERFILES EGRESADOS DE BOOTCAMPS DE LISTA DE BOOTCAMPS EN LA. 3 RONDAS DE INTENTOS Y MANDAN MUESTRA PEQUEÑA. SUGIEREN MUCHOS DE LOS CAMBIOS.abs

 #NEGOCIACIÓN, PERFILES Y CUÁNTO CUESTA. MAX 8MIL. CADA FALSO POSITIVO ES UN PROBLEMA. 
 # LLEGABAN A MIL, PARECIA QUE FP NO ERAN PROBLEMA: MEJOR ESTRATEGIA PALABRAS GENERALES Y TRAEMOS 5MIL PERFILES Y DENTRO DE ESA DEBEN DE ESTAR TODOS ESTUDIANTES DE PERFILES PROFESIONALES DE BOOTCAMPS.
 # EGRESADOS EN LATIRNOAMERICA DEBERÍAN SER MUCHO MÁS DE 8MIL, EJ: DIGITAL HOUSE HABLAN DE 100MIL EGRESADOS

 #NO REPRESENTATIVIDAD: MUCHOS EGRESADOS POCA MUESTRA, NO TODOS TIENEN PERFIL DE LINKED-IN

 #PRIORIDAD

# %%
#LOOP PARA BUSCAR SI EL INDIVIDUO TIENE FORMACIÓN EN ALGÚN BOOTCAMP
c = []
for boot in range(len(boots)): #PARA CADA BOOTCAMP
    for i in range(len(dfc.certifications)): #PARA CADA INDIVIDUO
        for h in range(len(dfc.certifications[i])): #DENTRO LA EDUCACIÓN DE CADA INDIVIDUO
            # if "title" in dfc.certifications[i][h]: #SI TIENE EL CAMPO EDUCACIÓN
            #     A = re.findall(boots[boot], dfc.certifications[i][h]["title"]) #REVISA SI ESTÁ EN UN BOOTCAMP
            #     if len(A) > 0 : #SI ESA REVISIÓN ES NO VACÍA
            #         c.append((dfc.id[i], boots[boot], lista_boots[boot], dfc.certifications[i][h]['title']))
            #         # c.append((dfe.id[i], h)) #AÑADE EL ID DE ESE INDIVIDUO Y EL LUGAR DONDE ESTÁ ESA EDUCACIÓN
            #         print(f"{dfc['job_title'][i]}---{A}---{boots[boot]}--{dfc.certifications[i][h]['title']} \n \n")
            
            if "certificate_authority" in dfc.certifications[i][h]: #SI TIENE EL CAMPO EDUCACIÓN
                A = re.findall(boots[boot], dfc.certifications[i][h]["certificate_authority"]) #REVISA SI ESTÁ EN UN BOOTCAMP
                if len(A) > 0 : #SI ESA REVISIÓN ES NO VACÍA
                    c.append((dfc.id[i], boots[boot], lista_boots[boot], dfc.certifications[i][h]['certificate_authority']))
                    # c.append((dfe.id[i], h)) #AÑADE EL ID DE ESE INDIVIDUO Y EL LUGAR DONDE ESTÁ ESA EDUCACIÓN
                    print(f"{dfc['job_title'][i]}---{A}---{boots[boot]}--{dfc.certifications[i][h]['certificate_authority']} \n \n")
                    


            #LOOP SIN INDICE
            # for edu in dfe.educacion[i]:
            # if "education" in edu:
            #     # print(boot, edu["education"])
            #     A = re.findall(boot, edu["education"])
            #     if len(A) > 0:
            #         c.append(A)
            #         m.append(boot)
            #         print(f" {dfe['job_title'][i]} -- {A} -- {boot} -- {edu['education']} \n \n")
            #         # print(f"{A} -- {boot} -- {edu['education']}")
# Out:
# ⚡ Full Stack Developer JavaScript---['acamica']---ac.mica--acamica
#
#
# ⚡ Full Stack Developer JavaScript---['acamica']---ac.mica--acamica
#
#
# ⚡ Full Stack Developer JavaScript---['acamica']---ac.mica--acamica
#
#
# ⚡ Full Stack Developer JavaScript---['acamica']---ac.mica--acamica
#
#
# Java Developer---['acamica']---ac.mica--acamica
#
#
# Java Developer---['acamica']---ac.mica--acamica
#
#
# Java Developer---['acamica']---ac.mica--acamica
#
#
# Java Developer---['acamica']---ac.mica--acamica
#
#
# Desarrollador de sistemas---['acamica']---ac.mica--acamica
#
#
# Desarrollador de sistemas---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Entrepreneur - Experience Manager---['acamica']---ac.mica--acamica
#
#
# Software Engineer / ScrumMaster---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Senior Consultant - Managed Services AEM Tech Leader---['acamica']---ac.mica--acamica
#
#
# Senior Consultant - Managed Services AEM Tech Leader---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# React Native developer---['acamica']---ac.mica--acamica
#
#
# Personal docente de informática---['acamica']---ac.mica--acamica
#
#
# Devops Sr. / SRE---['acamica']---ac.mica--acamica
#
#
# Devops Sr. / SRE---['acamica']---ac.mica--acamica
#
#
# Devops Sr. / SRE---['acamica']---ac.mica--acamica
#
#
# Devops Sr. / SRE---['acamica']---ac.mica--acamica
#
#
# Devops Sr. / SRE---['acamica']---ac.mica--acamica
#
#
# Diseñadora gráfica y web---['acamica']---ac.mica--acamica.com
#
#
# Profesional de Informática & Seguridad---['acamica']---ac.mica--acamica
#
#
# Sr Full Stack Engineer---['acamica']---ac.mica--acamica
#
#
# Software Engineer---['acamica']---ac.mica--acamica
#
#
# Software Engineer---['acamica']---ac.mica--acamica
#
#
# Software Engineer---['acamica']---ac.mica--acamica
#
#
# Web UI Developer---['acamica']---ac.mica--acamica
#
#
# Platform Analyst---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Software Developer---['acamica']---ac.mica--acamica
#
#
# Ingeniero y arquitecto de datos---['acamica']---ac.mica--acamica
#
#
# Ingeniero y arquitecto de datos---['acamica']---ac.mica--acamica
#
#
# UI Developer---['acamica']---ac.mica--acamica
#
#
# Analista de Sistemas, diplomado---['acamica']---ac.mica--acamica
#
#
# Branding & Comunicación para PYMES---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Data Entry---['acamica']---ac.mica--acamica
#
#
# Agile Practitioner---['acamica']---ac.mica--acamica
#
#
# Desarrollador Web Fullstack • Licenciado---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Jr.---['acamica']---ac.mica--acamica
#
#
# Diseñador gráfico---['acamica']---ac.mica--acamica
#
#
# Diseñador gráfico---['acamica']---ac.mica--acamica
#
#
# User Experience Designer---['acamica']---ac.mica--acamica
#
#
# User Experience Designer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# Ssr frontend developer---['acamica']---ac.mica--acamica
#
#
# DevOps---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# Desarrolo Front End---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# UX/UI Designer---['acamica']---ac.mica--acamica
#
#
# nan---['acamica']---ac.mica--acamica
#
#
# nan---['acamica']---ac.mica--acamica
#
#
# nan---['acamica']---ac.mica--acamica
#
#
# Desarrollador web---['desafio latam']---desaf.o[ -]?latam--desafio latam
#
#
# Diseñador Gráfico - Diseñador Web---['desafio latam']---desaf.o[ -]?latam--desafio latam
#
#
# UX Designer - Massive Entertainment---['desafio latam']---desaf.o[ -]?latam--academia desafio latam
#
#
# Service Team Manager---['icreate']---icreate[ -]?limited|icreate|icreate[ -]?coding[ -]?academy| icreate[ -]?coding--icreate consulting
#
#
# Full Stack Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Java Software Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Masters---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding®
#
#
# .Net Software Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS Tech Lead---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS Tech Lead---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS Tech Lead---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer---['keep coding']---keep.?coding|keep.?coding.io--keep coding
#
#
# Software Engineer---['keep coding']---keep.?coding|keep.?coding.io--keep coding
#
#
# Lead Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding.io
#
#
# Software Engineer II---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer II---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Data Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Data Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS Developer (Remote )---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Estudiante de Doctorado (FPI)---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# MoureDev Founder. Pilbeo Co-Founder. iOS & Android engineer. Freelance full-stack software developer.---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# VP Software Delivery and Head of Development---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Software Architect---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Ingeniero de software---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Ingeniero de software---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Senior Delivery Consultant---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Front-End Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Front-End Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Frontend web developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Java Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Java Software Engineer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Profesor en Formación Permanente.---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# iOS/Swift/Angular Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding®
#
#
# nan---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# nan---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Desarrollador de software---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Desarrollador de software---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Desarrollador de software---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Web developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding®
#
#
# Big Data Developer---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Security Analyst---['keepcoding']---keep.?coding|keep.?coding.io--keepcoding
#
#
# Plant Protection Products registration trials---['laboratoria ']---laborat.ria --uniwersytet warszawski i laboratoria badawcze jars sp. z o.o.
#
#
# Plant Protection Products registration trials---['laboratoria ']---laborat.ria --uniwersytet warszawski i laboratoria badawcze jars sp. z o.o.

# %%
#CREAR DATAFRAME

c = list(set(c))
educ_boots = pd.DataFrame.from_records(c, columns=['id', 'regex_bootcamp', 'bootcamp', "match"])

# %%
#HACER MERGE CON EL RESTO DE COLUMNAS
educ_boots = pd.merge(educ_boots, dfc, "left", "id")
educ_boots.to_excel(fileOut, index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-64ada9e696a5> in <module>
# ----> 1 df_educ
#
# NameError: name 'df_educ' is not defined
